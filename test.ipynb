# %%
# !ls
# Out:
# Fall-Detection-System-SisFall-Dataset-Raspberry-Pi
# README.md
# UCI HAR Dataset
# csv_format.txt
# data
# formating.ipynb
# model
# predict.ipynb
# sensor_data
# test.ipynb
# train_model.ipynb
